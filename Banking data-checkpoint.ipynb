# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("bank_marketing_updated_v1.csv",skiprows=2 )

# %%
df
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %%
df.dtypes
# Out:
# customerid      int64
# age           float64
# salary          int64
# balance         int64
# marital        object
# jobedu         object
# targeted       object
# default        object
# housing        object
# loan           object
# contact        object
# day             int64
# month          object
# duration       object
# campaign        int64
# pdays           int64
# previous        int64
# poutcome       object
# response       object
# dtype: object

# %%
df['age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 45211 entries, 0 to 45210
# Series name: age
# Non-Null Count  Dtype
# --------------  -----
# 45191 non-null  float64
# dtypes: float64(1)
# memory usage: 353.3 KB

# %%
df[df.age.isnull()]
# Out:
#        customerid  age  salary  balance   marital                   jobedu  \
# 161           162  NaN   60000       47    single      technician,tertiary
# 1021         1022  NaN   60000     -500   married     technician,secondary
# 1585         1586  NaN  100000      123  divorced     management,secondary
# 3943         3944  NaN   70000       62   married        services,tertiary
# 5675         5676  NaN   20000      -85   married      blue-collar,primary
# 6873         6874  NaN   70000     1336  divorced       services,secondary
# 9692         9693  NaN   50000     -162    single          admin.,tertiary
# 11653       11654  NaN    8000     2562    single       unemployed,primary
# 13417       13418  NaN   20000      452  divorced      blue-collar,primary
# 14541       14542  NaN   20000      -84   married    blue-collar,secondary
# 17159       17160  NaN  120000    -2082   married   entrepreneur,secondary
# ...

# %%
df.drop("customerid",axis=1,inplace=True)

# %%
df
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %%
#Dividing joedu into job and education

# %%
df['Job']=df.jobedu.apply(lambda x: x.split(',')[0])
df.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response           Job
# ...

# %%
df['Education']=df.jobedu.apply(lambda x: x.split(',')[1])

# %%
df
# Out:
#         age  salary  balance   marital                  jobedu targeted  \
# 0      58.0  100000     2143   married     management,tertiary      yes
# 1      44.0   60000       29    single    technician,secondary      yes
# 2      33.0  120000        2   married  entrepreneur,secondary      yes
# 3      47.0   20000     1506   married     blue-collar,unknown       no
# 4      33.0       0        1    single         unknown,unknown       no
# ...     ...     ...      ...       ...                     ...      ...
# 45206  51.0   60000      825   married     technician,tertiary      yes
# 45207  71.0   55000     1729  divorced         retired,primary      yes
# 45208  72.0   55000     5715   married       retired,secondary      yes
# 45209  57.0   20000      668   married   blue-collar,secondary      yes
# 45210  37.0  120000     2971   married  entrepreneur,secondary      yes
#
#       default housing loan    contact  day      month              duration  \
# ...

# %%
df.drop('jobedu',axis=1,inplace=True)

# %%
df
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
#df=df[df.month.apply(lambda x: isinstance(x,float))==True]
df
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
df.isnull().sum()
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# Job           0
# Education     0
# dtype: int64

# %%
 #Handling missing data

# %%
inp1=df[-df.age.isnull()].copy()

# %%
inp1.shape
# Out:
# (45191, 19)

# %%
inp1.age.isnull().sum()
# Out:
# np.int64(0)

# %%
inp1.isnull().sum()
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# Job           0
# Education     0
# dtype: int64

# %%
inp1[inp1.month.isnull()]
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 189    31.0  100000        0    single       no      no     yes   no
# 769    39.0   20000      245   married      yes      no     yes   no
# 860    33.0   55000      165   married      yes      no      no   no
# 1267   36.0   50000      114   married      yes      no     yes  yes
# 1685   34.0   20000      457   married      yes      no     yes   no
# 1899   49.0   16000      164  divorced      yes      no     yes   no
# 2433   26.0   60000     3825   married      yes      no     yes   no
# 2612   38.0   50000      446    single       no      no     yes   no
# 2747   48.0  120000     2550   married       no      no     yes   no
# 3556   41.0   20000       59   married      yes      no     yes   no
# 3890   56.0   55000     4391   married       no      no     yes   no
# 5311   22.0   20000        0    single      yes      no     yes   no
# 6265   32.0   50000       13    single      yes      no     yes   no
# ...

# %%
inp1.month.value_counts(normalize=True)
# Out:
# month
# may, 2017    0.304380
# jul, 2017    0.152522
# aug, 2017    0.138123
# jun, 2017    0.118141
# nov, 2017    0.087880
# apr, 2017    0.064908
# feb, 2017    0.058616
# jan, 2017    0.031058
# oct, 2017    0.016327
# sep, 2017    0.012760
# mar, 2017    0.010545
# dec, 2017    0.004741
# Name: proportion, dtype: float64

# %%
#normalize=True==> percentage of the values that are appearing

# %%
inp1.month.mode()[0]
# Out:
# 'may, 2017'

# %%
inp1.month.fillna(inp1.month.mode()[0],inplace=True)

# %%
inp1.month.isnull().sum()
# Out:
# np.int64(0)

# %%
inp1.isnull().sum()
# Out:
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# Job           0
# Education     0
# dtype: int64

# %%
inp1.response.value_counts(normalize=True)
# Out:
# response
# no     0.882974
# yes    0.117026
# Name: proportion, dtype: float64

# %%
inp1=inp1[-inp1.response.isnull()]

# %%
inp1.response.isnull().sum()
# Out:
# np.int64(0)

# %%
inp1.isnull().sum()
# Out:
# age          0
# salary       0
# balance      0
# marital      0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response     0
# Job          0
# Education    0
# dtype: int64

# %%
inp1.pdays.describe()
# Out:
# count    45161.000000
# mean        40.182015
# std        100.079372
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %% [markdown]
# # -1 indicates missing values

# %%
inp1[inp1['pdays']==-1].sum()
# Out:
# age                                                  1511015.0
# salary                                              2099711000
# balance                                               48704184
# marital      marriedsinglemarriedmarriedsinglemarriedsingle...
# targeted     yesyesyesnonoyesnonoyesyesyesyesyesnoyesyesnoy...
# default      nononononononoyesnonononononononononononononon...
# housing      yesyesyesyesnoyesyesyesyesyesyesyesyesyesyesye...
# loan         nonoyesnononoyesnononononononononononononoyesn...
# contact      unknownunknownunknownunknownunknownunknownunkn...
# day                                                     596055
# month        may, 2017may, 2017may, 2017may, 2017may, 2017m...
# duration     261 sec151 sec76 sec92 sec198 sec139 sec217 se...
# campaign                                                107837
# pdays                                                   -36915
# previous                                                     0
# ...

# %%
inp1.shape
# Out:
# (45161, 19)

# %%
(100.0*36915)/45161
# Out:
# 81.7408826199597

# %%
inp1.loc[inp1.pdays<0,"pdays"]=np.nan
inp1.pdays.describe()
# Out:
# count    8246.000000
# mean      224.542202
# std       115.210792
# min         1.000000
# 25%       133.000000
# 50%       195.000000
# 75%       327.000000
# max       871.000000
# Name: pdays, dtype: float64

# %%
import matplotlib.pyplot as plt , seaborn as sns

# %%
# %matplotlib inline

# %%
inp1
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact  day      month              duration  campaign  pdays  \
# ...

# %%
inp1.response.describe()
# Out:
# count     45161
# unique        2
# top          no
# freq      39876
# Name: response, dtype: object

# %% [markdown]
# ## Outlier handling

# %%
sns.boxplot(inp1.age)
# Out:
# <Axes: ylabel='age'>

# %%
inp1.age.plot.hist(edgecolor='orange')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ###### Balance

# %%
inp1.salary.describe()
# Out:
# count     45161.000000
# mean      57004.849317
# std       32087.698810
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
plt.figure(figsize=[8,2])
sns.boxplot(x=inp1.balance)
plt.show()

# %%
inp1.balance.quantile([0.5,0.7,0.9,0.95,0.99])
# Out:
# 0.50      448.0
# 0.70     1126.0
# 0.90     3576.0
# 0.95     5769.0
# 0.99    13173.4
# Name: balance, dtype: float64

# %%
inp1[inp1['balance']>15000].describe()
# Out:
#               age         salary        balance         day    campaign  \
# count  351.000000     351.000000     351.000000  351.000000  351.000000
# mean    45.341880   70008.547009   24295.780627   16.022792    2.749288
# std     12.114333   34378.272805   12128.560693    8.101819    3.036886
# min     23.000000       0.000000   15030.000000    1.000000    1.000000
# 25%     35.000000   50000.000000   17074.000000    9.000000    1.000000
# 50%     44.000000   60000.000000   20723.000000   18.000000    2.000000
# 75%     55.000000  100000.000000   26254.000000   21.000000    3.000000
# max     84.000000  120000.000000  102127.000000   31.000000   31.000000
#
#             pdays    previous
# count   62.000000  351.000000
# mean   188.516129    0.555556
# std    118.796388    1.784590
# min     31.000000    0.000000
# 25%     96.250000    0.000000
# 50%    167.500000    0.000000
# 75%    246.500000    0.000000
# max    589.000000   23.000000

# %%
# Instead of looking at the means and median we will gonna look for the quatilenns for the better result

# %%
sns.boxplot(x=inp1.salary)
# Out:
# <Axes: xlabel='salary'>

# %%
#Standardize variables

# %%
inp1.duration.describe()
# Out:
# count       45161
# unique       2646
# top       1.5 min
# freq          138
# Name: duration, dtype: object

# %%
inp1.duration
# Out:
# 0                     261 sec
# 1                     151 sec
# 2                      76 sec
# 3                      92 sec
# 4                     198 sec
#                  ...
# 45206    16.2833333333333 min
# 45207                 7.6 min
# 45208    18.7833333333333 min
# 45209    8.46666666666667 min
# 45210    6.01666666666667 min
# Name: duration, Length: 45161, dtype: object

# %%
inp1.duration.value_counts()
# Out:
# duration
# 1.5 min                 138
# 2.06666666666667 min    129
# 1.68333333333333 min    129
# 1.73333333333333 min    127
# 2.03333333333333 min    127
#                        ...
# 24.3333333333333 min      1
# 18.1166666666667 min      1
# 36.9833333333333 min      1
# 22.6833333333333 min      1
# 25.7166666666667 min      1
# Name: count, Length: 2646, dtype: int64

# %%
inp1.duration[:10]
# Out:
# 0    261 sec
# 1    151 sec
# 2     76 sec
# 3     92 sec
# 4    198 sec
# 5    139 sec
# 6    217 sec
# 7    380 sec
# 8     50 sec
# 9     55 sec
# Name: duration, dtype: object

# %%
inp1.duration=inp1.duration.apply(lambda x: float(x.split()[0])/60 if 'sec' in x else float(x.split()[0]))
# df['duration_in_seconds'] = df['duration'].apply(lambda x: float(x.split()[0]) * 60 if 'min' in x else float(x.split()[0]))

# %%
inp1.duration.describe()
# Out:
# count    45161.000000
# mean         4.302774
# std          4.293129
# min          0.000000
# 25%          1.716667
# 50%          3.000000
# 75%          5.316667
# max         81.966667
# Name: duration, dtype: float64

# %%
inp1.dtypes
# Out:
# age          float64
# salary         int64
# balance        int64
# marital       object
# targeted      object
# default       object
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration     float64
# campaign       int64
# pdays        float64
# previous       int64
# poutcome      object
# response      object
# Job           object
# Education     object
# dtype: object

# %%
inp1.month
# Out:
# 0        may, 2017
# 1        may, 2017
# 2        may, 2017
# 3        may, 2017
# 4        may, 2017
#            ...
# 45206    nov, 2017
# 45207    nov, 2017
# 45208    nov, 2017
# 45209    nov, 2017
# 45210    nov, 2017
# Name: month, Length: 45161, dtype: object

# %%
inp1.month=inp1.month.apply(lambda x : x.replace(',',''))

# %%
inp1.month
# Out:
# 0        may 2017
# 1        may 2017
# 2        may 2017
# 3        may 2017
# 4        may 2017
#            ...
# 45206    nov 2017
# 45207    nov 2017
# 45208    nov 2017
# 45209    nov 2017
# 45210    nov 2017
# Name: month, Length: 45161, dtype: object

# %%
inp1.day=inp1.day.astype(str)

# %%
inp1
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact day     month   duration  campaign  pdays  previous poutcome  \
# ...

# %%
inp1['day'] = inp1['day'].astype(str).str.cat(inp1['month'].astype(str), sep=' ')
inp1['day'] = pd.to_datetime(inp1['day'])

# %%
inp1.drop(columns = 'month', axis=1, inplace = True)

# %%
inp1
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 0      58.0  100000     2143   married      yes      no     yes   no
# 1      44.0   60000       29    single      yes      no     yes   no
# 2      33.0  120000        2   married      yes      no     yes  yes
# 3      47.0   20000     1506   married       no      no     yes   no
# 4      33.0       0        1    single       no      no      no   no
# ...     ...     ...      ...       ...      ...     ...     ...  ...
# 45206  51.0   60000      825   married      yes      no      no   no
# 45207  71.0   55000     1729  divorced      yes      no      no   no
# 45208  72.0   55000     5715   married      yes      no      no   no
# 45209  57.0   20000      668   married      yes      no      no   no
# 45210  37.0  120000     2971   married      yes      no      no   no
#
#          contact        day   duration  campaign  pdays  previous poutcome  \
# ...

# %%
# inp1.drop('month',axis=1,inplace=True)

# %%
inp1.dtypes
# Out:
# age                 float64
# salary                int64
# balance               int64
# marital              object
# targeted             object
# default              object
# housing              object
# loan                 object
# contact              object
# day          datetime64[ns]
# duration            float64
# campaign              int64
# pdays               float64
# previous              int64
# poutcome             object
# response             object
# Job                  object
# Education            object
# dtype: object

# %% [markdown]
# # Categorical unordered univariate analysis

# %%
inp1.marital.value_counts()
# Out:
# marital
# married     27185
# single      12778
# divorced     5198
# Name: count, dtype: int64

# %%
inp1.marital.value_counts(normalize=True).plot.barh()
plt.show()

# %%
inp1.Job.value_counts(normalize=True).plot.barh()
# Out:
# <Axes: ylabel='Job'>

# %%
blue_collar_data = inp1[inp1['Job'] == 'blue-collar']
plt.plot(Y=blue_collar_data['Education'], marker='o', label='Blue Collar')
plt.xlabel('Education')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
inp1.Education.value_counts(normalize=True).plot.pie()
# Out:
# <Axes: ylabel='proportion'>

# %% [markdown]
# # poutcome variable

# %%
inp1.poutcome.value_counts().plot.bar()
# Out:
# <Axes: xlabel='poutcome'>

# %%
inp1[-(inp1.poutcome=='unknown')].poutcome.value_counts(normalize=True).plot.bar()
# Out:
# <Axes: xlabel='poutcome'>

# %% [markdown]
# # response = the target variable

# %%
inp1.response.value_counts(normalize=True).plot.pie()
# Out:
# <Axes: ylabel='proportion'>

# %%
sns.boxplot(data=inp1,x="response",y='salary')
# Out:
# <Axes: xlabel='response', ylabel='salary'>

# %% [markdown]
# # Bi-variate Analysis

# %%
plt.scatter(inp1.salary,inp1.balance,alpha=0.4,s=4)

# %%
inp1.plot.scatter(x='age',y='balance')
# Out:
# <Axes: xlabel='age', ylabel='balance'>

# %%
sns.pairplot(data=inp1,vars=["salary","balance","age"])
plt.show()

# %% [markdown]
# # Quantify using correlation values

# %%
inp1[['age','salary','balance']].corr()
# Out:
#               age    salary   balance
# age      1.000000  0.024513  0.097710
# salary   0.024513  1.000000  0.055489
# balance  0.097710  0.055489  1.000000

# %%
sns.heatmap(inp1[['age','salary','balance']].corr(),annot=True,cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# # Categorical to numerical

# %%
inp1.groupby(by='response')['salary'].mean()
# Out:
# response
# no     56769.510482
# yes    58780.510880
# Name: salary, dtype: float64

# %%
inp1.groupby(by='response')['salary'].median()
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %%
sns.boxplot(data=inp1,x="response",y='salary')
# Out:
# <Axes: xlabel='response', ylabel='salary'>

# %% [markdown]
# # 75 percentile

# %%
sns.boxplot(data=inp1,x="response",y='balance')
# Out:
# <Axes: xlabel='response', ylabel='balance'>

# %%
inp1.groupby("response")['balance'].mean()
# Out:
# response
# no     1304.292281
# yes    1804.681362
# Name: balance, dtype: float64

# %%
inp1.groupby("response")['balance'].median()
# Out:
# response
# no     417.0
# yes    733.0
# Name: balance, dtype: float64

# %%
def p75(x):
    return np.quantile(x,0.75)

# %%
inp1.groupby("response")['balance'].aggregate(["mean","median",p75])
# Out:
#                  mean  median     p75
# response
# no        1304.292281   417.0  1345.0
# yes       1804.681362   733.0  2159.0

# %%
inp1.groupby("response")['balance'].aggregate(["mean","median",p75]).plot.barh()
# Out:
# <Axes: ylabel='response'>

# %%
inp1.groupby("Education")['salary'].aggregate(["mean","median"])
# Out:
#                    mean    median
# Education
# primary    34232.343910   20000.0
# secondary  49731.449525   55000.0
# tertiary   82880.249887  100000.0
# unknown    46529.633621   50000.0

# %% [markdown]
# # categorical-categorical

# %%
inp1["response_flag"]=np.where(inp1.response=='yes',1,0)

# %%
inp1.response_flag.value_counts(normalize=True)
# Out:
# response_flag
# 0    0.882974
# 1    0.117026
# Name: proportion, dtype: float64

# %%
inp1.response_flag.mean()
# Out:
# np.float64(0.1170257523084077)

# %% [markdown]
# # Education vs response rate

# %%
inp1.groupby(by="Education")['response_flag'].mean()
# Out:
# Education
# primary      0.086416
# secondary    0.105608
# tertiary     0.150083
# unknown      0.135776
# Name: response_flag, dtype: float64

# %% [markdown]
# # Marital vs response rate

# %%
inp1.groupby(by="marital")['response_flag'].mean()
# Out:
# marital
# divorced    0.119469
# married     0.101269
# single      0.149554
# Name: response_flag, dtype: float64

# %%
inp1.groupby(by="marital")['response_flag'].mean().plot.barh()
# Out:
# <Axes: ylabel='marital'>

# %%
inp1.groupby(by="housing")['response_flag'].mean().plot.barh()
# Out:
# <Axes: ylabel='housing'>

# %% [markdown]
# # Age vs response

# %%
sns.boxplot(data=inp1,x="response",y='age')
# Out:
# <Axes: xlabel='response', ylabel='age'>

# %%
# Making buckets from the age coulmns

# %%
inp1["age_bucket"]=pd.cut(inp1.age,[0,30,40,50,60,999],labels=("<30","30-40","40-50","50-60","60<"))

# %%
inp1["age_bucket"]
# Out:
# 0        50-60
# 1        40-50
# 2        30-40
# 3        40-50
# 4        30-40
#          ...
# 45206    50-60
# 45207      60<
# 45208      60<
# 45209    50-60
# 45210    30-40
# Name: age_bucket, Length: 45161, dtype: category
# Categories (5, object): ['<30' < '30-40' < '40-50' < '50-60' < '60<']

# %%
plt.figure(figsize=[10,4])
plt.subplot(1,2,1)
inp1.age_bucket.value_counts(normalize=True).plot.bar()
plt.subplot(1,2,2)
inp1.groupby("age_bucket")["response_flag"].mean().plot.bar()
plt.show()

# %%
inp1.groupby("Job")["response_flag"].mean().plot.bar()
# Out:
# <Axes: xlabel='Job'>

# %% [markdown]
# # More than 2 variable

# %%
res=pd.pivot_table(data=inp1,index="Education",columns="marital",values="response_flag")

# %%
res
# Out:
# marital    divorced   married    single
# Education
# primary    0.138852  0.075601  0.106808
# secondary  0.103559  0.094650  0.129271
# tertiary   0.137415  0.129835  0.183737
# unknown    0.142012  0.122519  0.162879

# %%
sns.heatmap(res,annot=True,cmap="RdYlGn")
# Out:
# <Axes: xlabel='marital', ylabel='Education'>

# %%
sns.heatmap(res,annot=True,cmap="RdYlGn",center=0.117)
# Out:
# <Axes: xlabel='marital', ylabel='Education'>

# %%
r=pd.pivot_table(data=inp1,index="Job",columns="marital",values="response_flag")

# %%
r
# Out:
# marital        divorced   married    single
# Job
# admin.         0.120160  0.113383  0.136153
# blue-collar    0.077644  0.062778  0.105760
# entrepreneur   0.083799  0.075843  0.113924
# housemaid      0.097826  0.072527  0.166667
# management     0.127928  0.126228  0.162254
# retired        0.283688  0.220682  0.120370
# self-employed  0.158273  0.079637  0.191874
# services       0.091241  0.074105  0.117696
# student        0.166667  0.185185  0.293850
# technician     0.083243  0.102767  0.132645
# unemployed     0.157895  0.132695  0.195000
# unknown        0.058824  0.103448  0.176471

# %%
sns.heatmap(r,annot=True,cmap="RdYlGn")
# Out:
# <Axes: xlabel='marital', ylabel='Job'>

# %%
sns.heatmap(r,annot=True,cmap="RdYlGn",center=0.117)
# Out:
# <Axes: xlabel='marital', ylabel='Job'>

# %%
d=pd.pivot_table(data=inp1,index="Education",columns="poutcome",values="response_flag")

# %%
sns.heatmap(d,annot=True,cmap="RdYlGn",center=0.2308)
# Out:
# <Axes: xlabel='poutcome', ylabel='Education'>

# %%
inp1["pdays"]
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 45206      NaN
# 45207      NaN
# 45208    184.0
# 45209      NaN
# 45210    188.0
# Name: pdays, Length: 45161, dtype: float64
